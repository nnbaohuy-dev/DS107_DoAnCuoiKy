# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from catboost import Pool, CatBoostClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, classification_report, confusion_matrix

# Giả định module này đã tồn tại trong project của bạn
from Data_preprocessing_CBD import data_preprocessing

# =====================================================================
# CÁC HÀM TIỆN ÍCH (UTILITIES)
# =====================================================================

def plot_confusion_matrix(y_true, y_pred, target_names, title='Ma trận Nhầm lẫn (Confusion Matrix) - CatBoost'):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=target_names, yticklabels=target_names)
    plt.ylabel('THỰC TẾ (True Label)', fontweight='bold')
    plt.xlabel('DỰ ĐOÁN (Predicted Label)', fontweight='bold')
    plt.title(title, fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()

def plot_loss_curve(model, title='Đồ thị Hàm Loss (Learning Curve) - CatBoost'):
    results = model.evals_result_
    epochs = len(results['learn']['MultiClass'])
    x_axis = range(0, epochs)
    
    plt.figure(figsize=(10, 6))
    plt.plot(x_axis, results['learn']['MultiClass'], label='Tập Train')
    plt.plot(x_axis, results['validation']['MultiClass'], label='Tập Validation')
    plt.legend()
    plt.title(title, fontsize=14, fontweight='bold')
    plt.xlabel('Số lượng cây (Iterations)')
    plt.ylabel('Mức độ sai sót (Log Loss / MultiClass)')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

def get_shap_feature_importance_optimized(model, X_train, X_val, y_val, top_n=30):
    print(f"\n[STAGE 1.5] Đang tính SHAP trên toàn bộ tập Validation ({X_val.shape[0]} dòng)...")
    start_shap = time.time()
    
    val_pool = Pool(data=X_val, label=y_val)
    raw_shap_values = model.get_feature_importance(data=val_pool, type='ShapValues', thread_count=-1)
    
    # Bỏ cột base_value ở cuối và gộp kết quả cho Multiclass
    shap_values = raw_shap_values[:, :, :-1] 
    shap_importance = np.abs(shap_values).mean(axis=0).sum(axis=0)
            
    if hasattr(X_train, 'columns'):
        feature_names = X_train.columns
    else:
        feature_names = [f'Feature_{i}' for i in range(X_train.shape[1])]
        
    feature_imp_df = pd.DataFrame({'Feature': feature_names, 'Importance': shap_importance})
    feature_imp_df = feature_imp_df.sort_values(by='Importance', ascending=False)
    top_features = feature_imp_df.head(top_n)
    
    plt.figure(figsize=(12, 10))
    sns.barplot(x='Importance', y='Feature', data=top_features, hue='Feature', palette='viridis', legend=False)
    plt.title(f'Top {top_n} Đặc trưng quan trọng nhất (Native SHAP)', fontsize=14, fontweight='bold')
    plt.xlabel('Tác động trung bình tới mô hình (Mean |SHAP|)', fontweight='bold')
    plt.tight_layout()
    plt.show()
    
    print(f"-> Hoàn thành SHAP trong {time.time() - start_shap:.2f} giây.")
    return feature_imp_df

# =====================================================================
# GIAI ĐOẠN 1: HUẤN LUYỆN BASELINE VÀ RÚT TRÍCH ĐẶC TRƯNG
# =====================================================================

print("="*50)
print("GIAI ĐOẠN 1: HUẤN LUYỆN BASELINE MÔ HÌNH")
print("="*50)

X_train, y_train, X_val, y_val, X_test, y_test = data_preprocessing()
print("-> Hoàn thành tải và xử lý dữ liệu.")

target_names = ["A", "AA", "AAA", "Bits", "C", "PB-I", "PB-II"]

model_baseline = CatBoostClassifier(
    iterations=6000,           
    learning_rate=0.05,        
    random_seed=42,            
    thread_count=-1,           
    loss_function='MultiClass', 
    eval_metric='MultiClass'
)

print("\nĐang huấn luyện Baseline (Có Early Stopping)...")
model_baseline.fit(
    X_train, y_train,
    eval_set=(X_val, y_val),   
    early_stopping_rounds=50, 
    verbose=200                
)

print("\nĐang dự đoán trên tập validation...")
# FIX: Thêm .flatten() cho Giai đoạn 1
start_time = time.time()
y_pred_base = model_baseline.predict(X_val).flatten() 
end_time = time.time()
    
predict_time = end_time - start_time

print(f"Thời gian dự đoán (Inference Time): {predict_time:.4f} giây")
print("\n--- ĐÁNH GIÁ (MACRO) ---")
print(f"Precision: {precision_score(y_val, y_pred_base, average='macro'):.4f}")
print(f"Recall:    {recall_score(y_val, y_pred_base, average='macro'):.4f}")
print(f"F1-score:  {f1_score(y_val, y_pred_base, average='macro'):.4f}")

print("\n--- ĐÁNH GIÁ (WEIGHTED) ---")
print(f"Precision: {precision_score(y_val, y_pred_base, average='weighted'):.4f}")
print(f"Recall:    {recall_score(y_val, y_pred_base, average='weighted'):.4f}")
print(f"F1-score:  {f1_score(y_val, y_pred_base, average='weighted'):.4f}")

print("\n--- TỔNG QUAN ---")
print(f"Accuracy:  {accuracy_score(y_val, y_pred_base):.4f}")

print("\n--- ĐỘ CHÍNH XÁC TỪNG LỚP ---")
print(classification_report(y_val, y_pred_base))

print("\n--- ĐANG HIỂN THỊ ĐỒ THỊ BASELINE ---")
plot_loss_curve(model_baseline, title='Learning Curve - Baseline CatBoost')
plot_confusion_matrix(y_val, y_pred_base, target_names, title='Ma trận Nhầm lẫn - Baseline')

# Chạy tính toán SHAP để lấy danh sách Features
all_importances_shap = get_shap_feature_importance_optimized(model_baseline, X_train, X_val, y_val, top_n=30)

# =====================================================================
# GIAI ĐOẠN 2: HUẤN LUYỆN LẠI (RETRAIN) VỚI TOP FEATURES
# =====================================================================

print("\n" + "="*50)
print("GIAI ĐOẠN 2: RETRAIN DỰA TRÊN TOP FEATURES TỪ SHAP")
print("="*50)

top_ns = [500, 1000, 1500]

for top_n in top_ns:
    print(f"\n{'*'*50}")
    print(f"ĐANG XỬ LÝ VỚI TOP {top_n} FEATURES")
    print(f"{'*'*50}")
    
    important_features = all_importances_shap.head(top_n)
    
    # Trích xuất ma trận dữ liệu đã giảm chiều
    if hasattr(X_train, 'columns'):
        selected_cols = important_features['Feature'].tolist()
        X_train_red = X_train[selected_cols]
        X_val_red   = X_val[selected_cols]
        X_test_red  = X_test[selected_cols]
    else:
        selected_idx = [int(n.split('_')[1]) for n in important_features['Feature']]
        X_train_red = X_train[:, selected_idx]
        X_val_red   = X_val[:, selected_idx]
        X_test_red  = X_test[:, selected_idx]

    # Khởi tạo mô hình mới
    model_final = CatBoostClassifier(
        iterations=6000,      
        learning_rate=0.05,     
        random_seed=42,
        thread_count=-1,
        loss_function='MultiClass', 
        early_stopping_rounds=50,
        task_type='CPU' 
    )

    print(f"Đang huấn luyện mô hình ({top_n} features)...")
    model_final.fit(
        X_train_red, y_train,
        eval_set=(X_val_red, y_val),
        verbose=200
    )

    print(f"\nĐang dự đoán trên tập validation...")
    start_time = time.time()
    y_pred_final = model_final.predict(X_val_red).flatten()
    end_time = time.time()
    
    predict_time = end_time - start_time

    print(f"\n--- ĐÁNH GIÁ MÔ HÌNH MỚI (TOP {top_n} FEATURES) ---")
    print(f"Thời gian dự đoán (Inference Time): {predict_time:.4f} giây")

    print("\n--- MACRO ---")
    print(f"Accuracy:  {accuracy_score(y_val, y_pred_final):.4f}")
    print(f"Precision: {precision_score(y_val, y_pred_final, average='macro'):.4f}")
    print(f"Recall:    {recall_score(y_val, y_pred_final, average='macro'):.4f}")
    print(f"F1-score:  {f1_score(y_val, y_pred_final, average='macro'):.4f}")

    print("\n--- WEIGHTED ---")
    print(f"Precision: {precision_score(y_val, y_pred_final, average='weighted'):.4f}")
    print(f"Recall:    {recall_score(y_val, y_pred_final, average='weighted'):.4f}")
    print(f"F1-score:  {f1_score(y_val, y_pred_final, average='weighted'):.4f}")
    print("\n--- TỔNG QUAN ---")
    print(f"Accuracy:  {accuracy_score(y_val, y_pred_final):.4f}")
    print("\n--- ĐỘ CHÍNH XÁC TỪNG LỚP ---")
    print(classification_report(y_val, y_pred_final))
    
    # Vẽ đồ thị cho từng mô hình cắt giảm
    plot_loss_curve(model_final, title=f'Learning Curve - CatBoost (Top {top_n})')
    plot_confusion_matrix(y_val, y_pred_final, target_names, title=f'Ma trận Nhầm lẫn (Top {top_n})')
# Out:
# ==================================================
# GIAI ĐOẠN 1: HUẤN LUYỆN BASELINE MÔ HÌNH
# ==================================================
# Đang đọc, trích xuất Hình học, HOG, Color Histogram và LBP...
# Đang chia tập dữ liệu đảm bảo Cân bằng Class và Chống Leakage...
# Đang chuẩn hóa với StandardScaler...
# Kích thước X_train: (12950, 2567)
# Kích thước X_val:   (2796, 2567)
# Kích thước X_test:  (2799, 2567)
# Xử lý dữ liệu hoàn tất!
# -> Hoàn thành tải và xử lý dữ liệu.
#
# Đang huấn luyện Baseline (Có Early Stopping)...
# 0:	learn: 1.8559584	test: 1.8660732	best: 1.8660732 (0)	total: 3.56s	remaining: 5h 55m 56s
# 200:	learn: 0.5476051	test: 0.6907332	best: 0.6907332 (200)	total: 8m 5s	remaining: 3h 53m 17s
# 400:	learn: 0.3890839	test: 0.5874540	best: 0.5874540 (400)	total: 15m 16s	remaining: 3h 33m 13s
# 600:	learn: 0.3188369	test: 0.5482980	best: 0.5482980 (600)	total: 21m 29s	remaining: 3h 13m 2s
# 800:	learn: 0.2734970	test: 0.5272954	best: 0.5272954 (800)	total: 27m 50s	remaining: 3h 43s
# 1000:	learn: 0.2425212	test: 0.5142853	best: 0.5142680 (999)	total: 34m 8s	remaining: 2h 50m 29s
# 1200:	learn: 0.2180405	test: 0.5031511	best: 0.5031306 (1199)	total: 40m 23s	remaining: 2h 41m 24s
# 1400:	learn: 0.1974608	test: 0.4950104	best: 0.4950104 (1400)	total: 46m 34s	remaining: 2h 32m 53s
# 1600:	learn: 0.1797326	test: 0.4883226	best: 0.4883135 (1599)	total: 52m 42s	remaining: 2h 24m 50s
# 1800:	learn: 0.1642124	test: 0.4815933	best: 0.4815933 (1800)	total: 59m 12s	remaining: 2h 18m 3s
# 2000:	learn: 0.1517840	test: 0.4770817	best: 0.4769733 (1998)	total: 1h 6m 15s	remaining: 2h 12m 25s
# 2200:	learn: 0.1399146	test: 0.4735398	best: 0.4735398 (2200)	total: 1h 13m 10s	remaining: 2h 6m 17s
# 2400:	learn: 0.1297664	test: 0.4703276	best: 0.4703276 (2400)	total: 1h 20m 10s	remaining: 2h 10s
# 2600:	learn: 0.1202405	test: 0.4671430	best: 0.4671338 (2592)	total: 1h 26m 59s	remaining: 1h 53m 40s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4658706147
# bestIteration = 2747
#
# Shrink model to first 2748 iterations.
#
# Đang dự đoán trên tập validation...
# Thời gian dự đoán (Inference Time): 0.1044 giây
#
# --- ĐÁNH GIÁ (MACRO) ---
# Precision: 0.8249
# Recall:    0.8271
# F1-score:  0.8235
#
# --- ĐÁNH GIÁ (WEIGHTED) ---
# Precision: 0.8257
# Recall:    0.8219
# F1-score:  0.8212
#
# --- TỔNG QUAN ---
# Accuracy:  0.8219
#
# --- ĐỘ CHÍNH XÁC TỪNG LỚP ---
#               precision    recall  f1-score   support
#
#            0       0.71      0.74      0.73       360
#            1       0.83      0.70      0.76       502
#            2       0.75      0.92      0.83       401
#            3       0.95      0.87      0.91       403
#            4       0.89      0.95      0.92       360
#            5       0.82      0.83      0.82       351
#            6       0.82      0.78      0.80       419
#
#     accuracy                           0.82      2796
#    macro avg       0.82      0.83      0.82      2796
# weighted avg       0.83      0.82      0.82      2796
#
#
# --- ĐANG HIỂN THỊ ĐỒ THỊ BASELINE ---
# [STAGE 1.5] Đang tính SHAP trên toàn bộ tập Validation (2796 dòng)...
# -> Hoàn thành SHAP trong 10.62 giây.
#
# ==================================================
# GIAI ĐOẠN 2: RETRAIN DỰA TRÊN TOP FEATURES TỪ SHAP
# ==================================================
#
# **************************************************
# ĐANG XỬ LÝ VỚI TOP 500 FEATURES
# **************************************************
# Đang huấn luyện mô hình (500 features)...
# 0:	learn: 1.8529576	test: 1.8604698	best: 1.8604698 (0)	total: 511ms	remaining: 51m 7s
# 200:	learn: 0.5292836	test: 0.6717951	best: 0.6717951 (200)	total: 1m 33s	remaining: 45m 9s
# 400:	learn: 0.3684661	test: 0.5689576	best: 0.5689576 (400)	total: 2m 55s	remaining: 40m 55s
# 600:	learn: 0.2917793	test: 0.5316099	best: 0.5316099 (600)	total: 4m 13s	remaining: 37m 57s
# 800:	learn: 0.2433349	test: 0.5099345	best: 0.5099345 (800)	total: 5m 31s	remaining: 35m 54s
# 1000:	learn: 0.2080180	test: 0.4941840	best: 0.4941840 (1000)	total: 6m 47s	remaining: 33m 56s
# 1200:	learn: 0.1823558	test: 0.4836051	best: 0.4835361 (1199)	total: 8m 4s	remaining: 32m 15s
# 1400:	learn: 0.1619635	test: 0.4765329	best: 0.4764753 (1396)	total: 9m 21s	remaining: 30m 42s
# 1600:	learn: 0.1454068	test: 0.4708665	best: 0.4708665 (1600)	total: 10m 35s	remaining: 29m 6s
# 1800:	learn: 0.1310066	test: 0.4660371	best: 0.4660371 (1800)	total: 11m 50s	remaining: 27m 36s
# 2000:	learn: 0.1185178	test: 0.4617554	best: 0.4617361 (1987)	total: 13m 4s	remaining: 26m 8s
# 2200:	learn: 0.1077282	test: 0.4588860	best: 0.4588860 (2200)	total: 14m 25s	remaining: 24m 54s
# 2400:	learn: 0.0983573	test: 0.4565490	best: 0.4563179 (2393)	total: 15m 45s	remaining: 23m 37s
# 2600:	learn: 0.0899694	test: 0.4540752	best: 0.4539943 (2598)	total: 17m 32s	remaining: 22m 55s
# 2800:	learn: 0.0822796	test: 0.4526285	best: 0.4526285 (2800)	total: 19m 11s	remaining: 21m 55s
# 3000:	learn: 0.0753937	test: 0.4511471	best: 0.4511471 (3000)	total: 20m 39s	remaining: 20m 38s
# 3200:	learn: 0.0692525	test: 0.4500187	best: 0.4499880 (3199)	total: 22m 2s	remaining: 19m 16s
# 3400:	learn: 0.0640601	test: 0.4491305	best: 0.4491305 (3400)	total: 23m 19s	remaining: 17m 49s
# 3600:	learn: 0.0593968	test: 0.4477929	best: 0.4477929 (3600)	total: 24m 36s	remaining: 16m 23s
# 3800:	learn: 0.0548761	test: 0.4474274	best: 0.4471664 (3756)	total: 26m	remaining: 15m 2s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4471663751
# bestIteration = 3756
#
# Shrink model to first 3757 iterations.
#
# Đang dự đoán trên tập validation...
#
# --- ĐÁNH GIÁ MÔ HÌNH MỚI (TOP 500 FEATURES) ---
# Thời gian dự đoán (Inference Time): 0.0301 giây
#
# --- MACRO ---
# Accuracy:  0.8283
# Precision: 0.8311
# Recall:    0.8331
# F1-score:  0.8299
#
# --- WEIGHTED ---
# Precision: 0.8317
# Recall:    0.8283
# F1-score:  0.8277
#
# --- TỔNG QUAN ---
# Accuracy:  0.8283
#
# --- ĐỘ CHÍNH XÁC TỪNG LỚP ---
#               precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74       360
#            1       0.83      0.72      0.77       502
#            2       0.76      0.93      0.84       401
#            3       0.95      0.87      0.90       403
#            4       0.90      0.95      0.92       360
#            5       0.82      0.83      0.83       351
#            6       0.82      0.80      0.81       419
#
#     accuracy                           0.83      2796
#    macro avg       0.83      0.83      0.83      2796
# weighted avg       0.83      0.83      0.83      2796
# **************************************************
# ĐANG XỬ LÝ VỚI TOP 1000 FEATURES
# **************************************************
# Đang huấn luyện mô hình (1000 features)...
# 0:	learn: 1.8524486	test: 1.8611173	best: 1.8611173 (0)	total: 1.24s	remaining: 2h 4m 22s
# 200:	learn: 0.5375782	test: 0.6806539	best: 0.6806539 (200)	total: 3m 18s	remaining: 1h 35m 24s
# 400:	learn: 0.3772459	test: 0.5777994	best: 0.5777994 (400)	total: 6m 29s	remaining: 1h 30m 43s
# 600:	learn: 0.2997553	test: 0.5399553	best: 0.5399553 (600)	total: 9m 7s	remaining: 1h 22m
# 800:	learn: 0.2527511	test: 0.5187061	best: 0.5187061 (800)	total: 11m 39s	remaining: 1h 15m 39s
# 1000:	learn: 0.2192006	test: 0.5043826	best: 0.5043826 (1000)	total: 14m 13s	remaining: 1h 11m 2s
# 1200:	learn: 0.1915713	test: 0.4928835	best: 0.4928235 (1196)	total: 16m 43s	remaining: 1h 6m 51s
# 1400:	learn: 0.1707548	test: 0.4840199	best: 0.4840199 (1400)	total: 19m 11s	remaining: 1h 2m 58s
# 1600:	learn: 0.1541425	test: 0.4781100	best: 0.4781100 (1600)	total: 21m 35s	remaining: 59m 20s
# 1800:	learn: 0.1393561	test: 0.4735819	best: 0.4735819 (1800)	total: 24m 1s	remaining: 56m 1s
# 2000:	learn: 0.1268929	test: 0.4693494	best: 0.4693112 (1998)	total: 26m 31s	remaining: 53m 1s
# 2200:	learn: 0.1158857	test: 0.4661981	best: 0.4661635 (2199)	total: 29m 2s	remaining: 50m 6s
# 2400:	learn: 0.1065863	test: 0.4635131	best: 0.4634877 (2397)	total: 31m 32s	remaining: 47m 16s
# 2600:	learn: 0.0980625	test: 0.4611310	best: 0.4611270 (2597)	total: 34m 2s	remaining: 44m 28s
# 2800:	learn: 0.0900381	test: 0.4588567	best: 0.4588303 (2799)	total: 36m 32s	remaining: 41m 43s
# 3000:	learn: 0.0829397	test: 0.4574713	best: 0.4573948 (2998)	total: 39m 2s	remaining: 39m
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4571985181
# bestIteration = 3055
#
# Shrink model to first 3056 iterations.
#
# Đang dự đoán trên tập validation...
#
# --- ĐÁNH GIÁ MÔ HÌNH MỚI (TOP 1000 FEATURES) ---
# Thời gian dự đoán (Inference Time): 0.0449 giây
#
# --- MACRO ---
# Accuracy:  0.8233
# Precision: 0.8264
# Recall:    0.8284
# F1-score:  0.8250
#
# --- WEIGHTED ---
# Precision: 0.8270
# Recall:    0.8233
# F1-score:  0.8226
#
# --- TỔNG QUAN ---
# Accuracy:  0.8233
#
# --- ĐỘ CHÍNH XÁC TỪNG LỚP ---
#               precision    recall  f1-score   support
#
#            0       0.72      0.74      0.73       360
#            1       0.83      0.70      0.76       502
#            2       0.75      0.92      0.83       401
#            3       0.95      0.87      0.91       403
#            4       0.89      0.96      0.92       360
#            5       0.82      0.81      0.82       351
#            6       0.81      0.80      0.81       419
#
#     accuracy                           0.82      2796
#    macro avg       0.83      0.83      0.82      2796
# weighted avg       0.83      0.82      0.82      2796
# **************************************************
# ĐANG XỬ LÝ VỚI TOP 1500 FEATURES
# **************************************************
# Đang huấn luyện mô hình (1500 features)...
# 0:	learn: 1.8615140	test: 1.8706927	best: 1.8706927 (0)	total: 1.76s	remaining: 2h 56m 16s
# 200:	learn: 0.5406139	test: 0.6836903	best: 0.6836903 (200)	total: 4m 15s	remaining: 2h 3m
# 400:	learn: 0.3789356	test: 0.5809487	best: 0.5809487 (400)	total: 8m 11s	remaining: 1h 54m 19s
# 600:	learn: 0.3027292	test: 0.5417228	best: 0.5417228 (600)	total: 12m 2s	remaining: 1h 48m 9s
# 800:	learn: 0.2562603	test: 0.5217198	best: 0.5217190 (799)	total: 15m 54s	remaining: 1h 43m 18s
# 1000:	learn: 0.2228979	test: 0.5067410	best: 0.5067410 (1000)	total: 19m 41s	remaining: 1h 38m 22s
# 1200:	learn: 0.1968105	test: 0.4954099	best: 0.4954099 (1200)	total: 23m 31s	remaining: 1h 33m 58s
# 1400:	learn: 0.1753653	test: 0.4865945	best: 0.4865945 (1400)	total: 27m 15s	remaining: 1h 29m 28s
# 1600:	learn: 0.1582234	test: 0.4806621	best: 0.4806621 (1600)	total: 30m 59s	remaining: 1h 25m 8s
# 1800:	learn: 0.1439954	test: 0.4750053	best: 0.4750053 (1800)	total: 34m 41s	remaining: 1h 20m 53s
# 2000:	learn: 0.1312424	test: 0.4710850	best: 0.4710807 (1990)	total: 38m 24s	remaining: 1h 16m 45s
# 2200:	learn: 0.1202517	test: 0.4672658	best: 0.4672658 (2200)	total: 42m 18s	remaining: 1h 13m
# 2400:	learn: 0.1100636	test: 0.4646360	best: 0.4646360 (2400)	total: 46m 11s	remaining: 1h 9m 14s
# 2600:	learn: 0.1010546	test: 0.4611456	best: 0.4611456 (2600)	total: 49m 55s	remaining: 1h 5m 13s
# 2800:	learn: 0.0933270	test: 0.4591104	best: 0.4591104 (2800)	total: 53m 49s	remaining: 1h 1m 28s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.4587490139
# bestIteration = 2818
#
# Shrink model to first 2819 iterations.
#
# Đang dự đoán trên tập validation...
#
# --- ĐÁNH GIÁ MÔ HÌNH MỚI (TOP 1500 FEATURES) ---
# Thời gian dự đoán (Inference Time): 0.0378 giây
#
# --- MACRO ---
# Accuracy:  0.8269
# Precision: 0.8301
# Recall:    0.8314
# F1-score:  0.8286
#
# --- WEIGHTED ---
# Precision: 0.8304
# Recall:    0.8269
# F1-score:  0.8264
#
# --- TỔNG QUAN ---
# Accuracy:  0.8269
#
# --- ĐỘ CHÍNH XÁC TỪNG LỚP ---
#               precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74       360
#            1       0.83      0.72      0.77       502
#            2       0.75      0.92      0.83       401
#            3       0.94      0.87      0.91       403
#            4       0.90      0.95      0.92       360
#            5       0.83      0.81      0.82       351
#            6       0.83      0.80      0.81       419
#
#     accuracy                           0.83      2796
#    macro avg       0.83      0.83      0.83      2796
# weighted avg       0.83      0.83      0.83      2796

# %%
top_n = 500

print(f"\n{'*'*50}")
print(f"ĐANG XỬ LÝ VỚI TOP {top_n} FEATURES")
print(f"{'*'*50}")

important_features = all_importances_shap.head(top_n)

# Trích xuất ma trận dữ liệu đã giảm chiều
if hasattr(X_train, 'columns'):
    selected_cols = important_features['Feature'].tolist()
    X_train_red = X_train[selected_cols]
    X_val_red   = X_val[selected_cols]
    X_test_red  = X_test[selected_cols]
else:
    selected_idx = [int(n.split('_')[1]) for n in important_features['Feature']]
    X_train_red = X_train[:, selected_idx]
    X_val_red   = X_val[:, selected_idx]
    X_test_red  = X_test[:, selected_idx]

if hasattr(X_train_red, 'columns'):
    X_train_full = pd.concat([X_train_red, X_val_red], axis=0).reset_index(drop=True)
    y_train_full = pd.concat([pd.Series(y_train), pd.Series(y_val)], axis=0).reset_index(drop=True)
else:
    X_train_full = np.concatenate((X_train_red, X_val_red), axis=0)
    y_train_full = np.concatenate((y_train, y_val), axis=0)

# Khởi tạo mô hình mới
model_final = CatBoostClassifier(
    iterations=3756,      
    learning_rate=0.05,     
    random_seed=42,
    thread_count=-1,
    loss_function='MultiClass', 
    task_type='CPU' 
)

print(f"Đang huấn luyện mô hình ({top_n} features)...")
model_final.fit(
    X_train_full, y_train_full,
    verbose=200
)

print(f"\nĐang dự đoán trên tập validation...")
start_time = time.time()
y_pred_final = model_final.predict(X_test_red).flatten()
end_time = time.time()

predict_time = end_time - start_time

print(f"\n--- ĐÁNH GIÁ MÔ HÌNH MỚI (TOP {top_n} FEATURES) ---")
print(f"Thời gian dự đoán (Inference Time): {predict_time:.4f} giây")

print("\n--- MACRO ---")
print(f"Accuracy:  {accuracy_score(y_test, y_pred_final):.4f}")
print(f"Precision: {precision_score(y_test, y_pred_final, average='macro'):.4f}")
print(f"Recall:    {recall_score(y_test, y_pred_final, average='macro'):.4f}")
print(f"F1-score:  {f1_score(y_test, y_pred_final, average='macro'):.4f}")

print("\n--- WEIGHTED ---")
print(f"Precision: {precision_score(y_test, y_pred_final, average='weighted'):.4f}")
print(f"Recall:    {recall_score(y_test, y_pred_final, average='weighted'):.4f}")
print(f"F1-score:  {f1_score(y_test, y_pred_final, average='weighted'):.4f}")
print("\n--- TỔNG QUAN ---")
print(f"Accuracy:  {accuracy_score(y_test, y_pred_final):.4f}")
print("\n--- ĐỘ CHÍNH XÁC TỪNG LỚP ---")
print(classification_report(y_test, y_pred_final))

plot_confusion_matrix(y_test, y_pred_final, target_names, title=f'Ma trận Nhầm lẫn (Top {top_n})')
# Out:
# **************************************************
# ĐANG XỬ LÝ VỚI TOP 500 FEATURES
# **************************************************
# Đang huấn luyện mô hình (500 features)...
# 0:	learn: 1.8513557	total: 504ms	remaining: 31m 30s
# 200:	learn: 0.5437580	total: 1m 43s	remaining: 30m 24s
# 400:	learn: 0.3864895	total: 3m 10s	remaining: 26m 29s
# 600:	learn: 0.3098183	total: 4m 34s	remaining: 24m 3s
# 800:	learn: 0.2611781	total: 5m 58s	remaining: 22m 3s
# 1000:	learn: 0.2269061	total: 7m 22s	remaining: 20m 17s
# 1200:	learn: 0.2009693	total: 8m 44s	remaining: 18m 36s
# 1400:	learn: 0.1800833	total: 10m 6s	remaining: 16m 59s
# 1600:	learn: 0.1630010	total: 11m 27s	remaining: 15m 25s
# 1800:	learn: 0.1479815	total: 12m 48s	remaining: 13m 54s
# 2000:	learn: 0.1356932	total: 14m 10s	remaining: 12m 26s
# 2200:	learn: 0.1240221	total: 15m 33s	remaining: 10m 59s
# 2400:	learn: 0.1144456	total: 16m 53s	remaining: 9m 32s
# 2600:	learn: 0.1055625	total: 18m 12s	remaining: 8m 5s
# 2800:	learn: 0.0981163	total: 19m 31s	remaining: 6m 39s
# 3000:	learn: 0.0911517	total: 20m 49s	remaining: 5m 14s
# 3200:	learn: 0.0846125	total: 22m 9s	remaining: 3m 50s
# 3400:	learn: 0.0786565	total: 23m 28s	remaining: 2m 26s
# 3600:	learn: 0.0734367	total: 24m 46s	remaining: 1m 3s
# 3755:	learn: 0.0696833	total: 25m 48s	remaining: 0us
#
# Đang dự đoán trên tập validation...
#
# --- ĐÁNH GIÁ MÔ HÌNH MỚI (TOP 500 FEATURES) ---
# Thời gian dự đoán (Inference Time): 0.0276 giây
#
# --- MACRO ---
# Accuracy:  0.8610
# Precision: 0.8596
# Recall:    0.8648
# F1-score:  0.8604
#
# --- WEIGHTED ---
# Precision: 0.8615
# Recall:    0.8610
# F1-score:  0.8595
#
# --- TỔNG QUAN ---
# Accuracy:  0.8610
#
# --- ĐỘ CHÍNH XÁC TỪNG LỚP ---
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77       412
#            1       0.87      0.75      0.81       461
#            2       0.81      0.94      0.87       354
#            3       0.91      0.98      0.94       406
#            4       0.95      0.94      0.94       411
#            5       0.85      0.84      0.85       403
#            6       0.82      0.87      0.84       352
#
#     accuracy                           0.86      2799
#    macro avg       0.86      0.86      0.86      2799
# weighted avg       0.86      0.86      0.86      2799
